# %% [markdown]
# Activate the created conda environment - associated Jupyter kernel.
#
# * Challenges:
#     * Pymanopt needed to be updated (pymanopt.solvers -> pymanopt.optimizers)
#     * in `manifold_analysis_corr.CGmanopt`
#         * add decorator to cost function
#         * replace Xopt = solver.solve(problem) by Xopt = solver.run(problem).point

# %%
# SETUP PACKAGES 
# %load_ext autoreload
# %autoreload 2
import numpy as np
from mftma.manifold_analysis_correlation import manifold_analysis_corr
from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# generate dataset
np.random.seed(0)
X = [np.random.randn(5000, 50) for i in range(100)] # Replace this with data to analyze

# %%
# takes 1m 57
kappa = 0
n_t = 200
capacity_all, radius_all, dimension_all, center_correlation, K = manifold_analysis_corr(X, kappa, n_t)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Optimizing...
# Iteration    Cost                       Gradient norm
# ---------    -----------------------    --------------
#    1         +5.2014821216891463e+01    7.09378325e-02
#    2         +5.1997072513085733e+01    4.90413715e-02
#    3         +5.1981934863585330e+01    3.86091759e-02
#    4         +5.1972312856621215e+01    3.31649925e-02
#    5         +5.1965309563354282e+01    2.36176297e-02
#    6         +5.1961979205393803e+01    1.65251474e-02
#    7         +5.1960287715390720e+01    1.39477263e-02
#    8         +5.1958292942974104e+01    1.33096836e-02
#    9         +5.1957797421680041e+01    8.64679195e-03
#   10         +5.1957486682679360e+01    5.44015709e-03
#   11         +5.1957211697515064e+01    5.24494863e-03
#   12         +5.1957062502906304e+01    3.52992016e-03
#   13         +5.1956989265541395e+01    2.50973131e-03
# ...

# %%
plt.plot(capacity_all)

# %%
plt.plot(radius_all)

# %%
plt.plot(dimension_all)

# %%
center_correlation
# Out:
# 0.014050014117089296

# %%
K
# Out:
# 1
